# %% [markdown]
# Note: Most of the code was adapted from DR. Tony Diana's Data 602(Machine Learning) Notebooks

# %%
#installing lazypedict
# !pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.7/dist-packages (0.2.9)
# Requirement already satisfied: pandas==1.0.5 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.5)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: PyYAML==5.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.3.1)
# Requirement already satisfied: joblib==1.0.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.0)
# Requirement already satisfied: xgboost==1.1.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.1.1)
# Requirement already satisfied: tqdm==4.56.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (4.56.0)
# Requirement already satisfied: lightgbm==2.3.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (2.3.1)
# Requirement already satisfied: scipy==1.5.4 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.5.4)
# Requirement already satisfied: pytest==5.4.3 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (5.4.3)
# Requirement already satisfied: numpy==1.19.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.19.1)
# Requirement already satisfied: scikit-learn==0.23.1 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (0.23.1)
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==1.0.5->lazypredict) (2018.9)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (8.12.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (1.11.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (4.8.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.2.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest==5.4.3->lazypredict) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.23.1->lazypredict) (3.0.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.12->pytest==5.4.3->lazypredict) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest==5.4.3->lazypredict) (3.0.6)

# %%
#importing all packages
import pandas as pd
from pandas import DataFrame
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics, ensemble
from sklearn.metrics import classification_report, plot_confusion_matrix, accuracy_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from math import sqrt
import lazypredict
from lazypredict.Supervised import LazyClassifier
from lazypredict.Supervised import LazyRegressor
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from tensorflow.keras.layers import Dense, Dropout, Activation 
from tensorflow.keras.models import Model, Sequential 
from tensorflow.keras.optimizers import Adam
from sklearn.decomposition import PCA 
from sklearn.cluster import AgglomerativeClustering 
from sklearn.metrics import silhouette_score 
import scipy.cluster.hierarchy as shc 
from mpl_toolkits.mplot3d import Axes3D
from sklearn.ensemble import ExtraTreesRegressor
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
all_df = pd.read_csv('/content/drive/Shareddrives/DATA 602 Final Project/NATIONAL_GRAD_FINANCE_RACE_CLEAN.csv', error_bad_lines= False)

# %%
#creating dataframe for NY
ny_df = pd.read_csv('/content/drive/Shareddrives/DATA 602 Final Project/NY_GRAD_FINANCE_RACE_CLEAN.csv')
ny_df.head()
# Out:
#    Unnamed: 0       NCESSCH          TITLEI  ...  MATH_PCT  READ_NUM READ_PCT
# 0       10560  361938005859  Not Applicable  ...     95.00     50.59    95.00
# 1       10561  360585005857             Yes  ...     70.00     50.59    70.00
# 2       10562  360585000297             Yes  ...     75.00     50.59    80.00
# 3       10563  360585000301             Yes  ...     80.00     50.59    65.00
# 4       10564  360585000307             Yes  ...     85.00     50.59    85.00
#
# [5 rows x 36 columns]

# %%
#creating dataframe for DMV
dmv_df = pd.read_csv('/content/drive/Shareddrives/DATA 602 Final Project/DMV_GRAD_FINANCE_RACE_CLEAN.csv')
dmv_df.head()
# Out:
#    Unnamed: 0       NCESSCH          TITLEI  ...  MATH_PCT  READ_NUM READ_PCT
# 0        3268  110003000264  Not Applicable  ...     20.00     19.00    20.00
# 1        3269  110003000267  Not Applicable  ...     30.00    171.00    65.00
# 2        3270  110003000008  Not Applicable  ...      5.00    136.00     6.00
# 3        3271  110003000016  Not Applicable  ...     15.00    141.00    55.00
# 4        3272  110003000055  Not Applicable  ...      6.00     94.00    15.00
#
# [5 rows x 36 columns]

# %%
#dropping columns that won't be used for modeling
ny_df.drop(['TITLEI', 'Unnamed: 0','NCESSCH','LEAID','G12', 'SCHOOL_LEVEL','STNAM', 'PCT_MEN', 'PCT_FEN', 'PCT_FRL','FIPST','CWD_COHORT', 'ECD_COHORT', 'FCS_COHORT', 'HOM_COHORT', 'LEP_COHORT'],axis=1, inplace= True)

# %%
#dropping columns that won't be used for modeling
dmv_df.drop(['TITLEI', 'Unnamed: 0','NCESSCH','LEAID','G12','SCHOOL_LEVEL','STNAM','PCT_MEN', 'PCT_FEN', 'PCT_FRL','FIPST','CWD_COHORT', 'ECD_COHORT', 'FCS_COHORT', 'HOM_COHORT', 'LEP_COHORT'],axis=1, inplace= True)

# %%
#checking for nulls in NY dataframe
ny_df.isnull().sum()
# Out:
# TOTFRL          0
# FTE             0
# STUTERATIO      2
# TOTMENROL       0
# TOTFENROL       0
# SCHOOL_TYPE     0
# ALL_RATE        0
# ALL_COHORT      0
# MAM_COHORT      0
# MAS_COHORT      0
# MBL_COHORT      0
# MHI_COHORT      0
# MTR_COHORT      0
# MWH_COHORT      0
# Success_Rate    0
# PPCSTOT         0
# MATH_NUM        0
# MATH_PCT        0
# READ_NUM        0
# READ_PCT        0
# dtype: int64

# %%
#dropping nulls in NY dataframe
ny_df.dropna(inplace=True)

# %%
#checking for nulls in DMV dataframe
dmv_df.isnull().sum()
# Out:
# TOTFRL          0
# FTE             0
# STUTERATIO      8
# TOTMENROL       2
# TOTFENROL       1
# SCHOOL_TYPE     0
# ALL_RATE        0
# ALL_COHORT      0
# MAM_COHORT      0
# MAS_COHORT      0
# MBL_COHORT      0
# MHI_COHORT      0
# MTR_COHORT      0
# MWH_COHORT      0
# Success_Rate    0
# PPCSTOT         0
# MATH_NUM        0
# MATH_PCT        0
# READ_NUM        0
# READ_PCT        0
# dtype: int64

# %%
#dropping nulls in DMV dataframe
dmv_df.dropna(inplace=True)

# %% [markdown]
# **Correlation Matrix**

# %%
#creating correlation matrix for NY
plt.figure(figsize = (15,8))
corrMatrix = ny_df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
#creating correlation matrix for DMV
plt.figure(figsize = (15,8))
corrMatrix = dmv_df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
#dropping binary success rate for regression df
ny_regression = ny_df.drop(['Success_Rate'], axis=1)

# %%
#dropping continuous all rate for classification df
ny_classification = ny_df.drop(['ALL_RATE'], axis=1)

# %%
#dropping binary success rate for regression df
dmv_regression = dmv_df.drop(['Success_Rate'], axis=1)

# %%
#dropping continuous all rate for classification df
dmv_classification = dmv_df.drop(['ALL_RATE'], axis=1)

# %% [markdown]
# **STATS**

# %%
#distribution of target variable for entire U.S.
all_df['Success_Rate'].hist(bins =2)

# %%
#distribution of target variable for NY
ny_classification['Success_Rate'].hist(bins =2)

# %%
#distribution of target variable for DMV
dmv_classification['Success_Rate'].hist(bins =2)

# %%
#average grad rate per region
m1 = np.mean(ny_regression['ALL_RATE'])
print("Average NY grad rate:", m1)

m2 = np.mean(dmv_regression['ALL_RATE'])
print("Average DMV grad rate:", m2)
# Out:
# Average NY grad rate: 87.03980891719745
# Average DMV grad rate: 84.4884156630634

# %% [markdown]
# **Using Lazy Predict on NY Data to find the best Models**

# %% [markdown]
# **Lazy Regressor**

# %%
#creating y variable with all rate
y_reg = ny_regression.pop('ALL_RATE')
y_reg=y_reg.astype('int')
print(y_reg)
# Out:
# 0      95
# 1      50
# 2      90
# 3      45
# 4      80
#        ..
# 625    76
# 626    80
# 627    80
# 628    75
# 629    80
# Name: ALL_RATE, Length: 628, dtype: int64

# %%
#creating x variable with the other values in the NY regression dataframe
X_reg = ny_regression.values
X_reg.shape
print(X_reg)
# Out:
# [[ 85.          27.02000046  11.4        ...  95.          50.59406569
#    95.        ]
#  [585.          51.00999832  14.3        ...  70.          50.59406569
#    70.        ]
#  [434.          67.01999664  10.8        ...  75.          50.59406569
#    80.        ]
#  ...
#  [159.          27.01000023  10.6        ...  90.          50.59406569
#    90.        ]
#  [382.          49.02999878  12.5        ...  90.          50.59406569
#    90.        ]
#  [ 93.          23.85000038   7.5        ...  80.          50.59406569
#    80.        ]]

# %%
#split the test and train data 70/30
X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(X_reg, y_reg, test_size= 0.3, random_state=42)

# %%
#initialize the lazyregressor
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)

# %%
#fit the data
models, predictions = reg.fit(X_reg_train, X_reg_test, y_reg_train, y_reg_test)
# Out:
# 100%|██████████| 42/42 [00:04<00:00,  9.20it/s]

# %%
#visualize the results in the form of a dataframe
data=pd.DataFrame(models)
data
# Out:
#                                Adjusted R-Squared  ...  Time Taken
# Model                                              ...
# BayesianRidge                                0.46  ...        0.02
# RidgeCV                                      0.46  ...        0.03
# ElasticNetCV                                 0.46  ...        0.09
# Ridge                                        0.46  ...        0.02
# TransformedTargetRegressor                   0.46  ...        0.02
# LinearRegression                             0.46  ...        0.02
# LinearSVR                                    0.46  ...        0.02
# LassoCV                                      0.46  ...        0.12
# LassoLarsCV                                  0.46  ...        0.06
# LassoLarsIC                                  0.46  ...        0.02
# LarsCV                                       0.46  ...        0.06
# SGDRegressor                                 0.46  ...        0.02
# RandomForestRegressor                        0.46  ...        0.48
# GradientBoostingRegressor                    0.46  ...        0.22
# Lasso                                        0.45  ...        0.02
# PoissonRegressor                             0.45  ...        0.03
# ExtraTreesRegressor                          0.45  ...        0.28
# OrthogonalMatchingPursuitCV                  0.45  ...        0.03
# HistGradientBoostingRegressor                0.44  ...        0.49
# HuberRegressor                               0.44  ...        0.05
# LGBMRegressor                                0.44  ...        0.09
# BaggingRegressor                             0.43  ...        0.07
# ElasticNet                                   0.43  ...        0.03
# GammaRegressor                               0.42  ...        0.02
# GeneralizedLinearRegressor                   0.42  ...        0.04
# TweedieRegressor                             0.42  ...        0.02
# OrthogonalMatchingPursuit                    0.41  ...        0.02
# XGBRegressor                                 0.41  ...        0.16
# KNeighborsRegressor                          0.36  ...        0.02
# AdaBoostRegressor                            0.34  ...        0.15
# ExtraTreeRegressor                           0.20  ...        0.02
# NuSVR                                        0.11  ...        0.05
# SVR                                          0.10  ...        0.04
# DecisionTreeRegressor                        0.05  ...        0.02
# PassiveAggressiveRegressor                  -0.06  ...        0.02
# DummyRegressor                              -0.12  ...        0.02
# LassoLars                                   -0.12  ...        0.02
# RANSACRegressor                             -0.28  ...        0.11
# MLPRegressor                                -4.96  ...        1.33
# GaussianProcessRegressor                    -7.04  ...        0.06
# KernelRidge                                -43.75  ...        0.03
# Lars                           -18534468813578.40  ...        0.07
#
# [42 rows x 4 columns]

# %% [markdown]
# **Lazy Classifier**

# %%
#creating the y variable using success rate
y_clf = ny_classification.pop('Success_Rate')
y_clf=y_clf.astype('int')
print(y_clf)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 625    1
# 626    1
# 627    1
# 628    1
# 629    1
# Name: Success_Rate, Length: 628, dtype: int64

# %%
#creating the x variable using the other values in NY classification dataframe
X_clf = ny_classification.values
X_clf.shape
# Out:
# (628, 18)

# %%
#split the data 70/30
X_clf_train, X_clf_test, y_clf_train, y_clf_test = train_test_split(X_clf, y_clf, test_size= 0.3, random_state=42)

# %%
#initialize lazyclassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric = None)

# %%
#fit the data
models,predictions = clf.fit(X_clf_train, X_clf_test, y_clf_train, y_clf_test)
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 22.81it/s]

# %%
#visualize the results
data= pd.DataFrame(models)
data
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# AdaBoostClassifier                 0.97  ...        0.15
# LinearDiscriminantAnalysis         0.97  ...        0.03
# NearestCentroid                    0.95  ...        0.02
# RandomForestClassifier             0.98  ...        0.21
# XGBClassifier                      0.97  ...        0.06
# LinearSVC                          0.97  ...        0.03
# LGBMClassifier                     0.97  ...        0.09
# DecisionTreeClassifier             0.97  ...        0.03
# QuadraticDiscriminantAnalysis      0.89  ...        0.02
# Perceptron                         0.96  ...        0.02
# RidgeClassifierCV                  0.98  ...        0.02
# RidgeClassifier                    0.98  ...        0.02
# LogisticRegression                 0.97  ...        0.04
# SGDClassifier                      0.96  ...        0.02
# CalibratedClassifierCV             0.97  ...        0.05
# ExtraTreesClassifier               0.97  ...        0.15
# PassiveAggressiveClassifier        0.95  ...        0.02
# LabelSpreading                     0.95  ...        0.05
# LabelPropagation                   0.95  ...        0.04
# KNeighborsClassifier               0.96  ...        0.03
# BaggingClassifier                  0.95  ...        0.05
# BernoulliNB                        0.93  ...        0.01
# SVC                                0.95  ...        0.02
# ExtraTreeClassifier                0.95  ...        0.02
# GaussianNB                         0.25  ...        0.02
# DummyClassifier                    0.90  ...        0.02
#
# [26 rows x 5 columns]

# %%
#get feature names to use later
feature_names = ny_classification.columns
print(feature_names)
# Out:
# Index(['TOTFRL', 'FTE', 'STUTERATIO', 'TOTMENROL', 'TOTFENROL', 'SCHOOL_TYPE',
#        'ALL_COHORT', 'MAM_COHORT', 'MAS_COHORT', 'MBL_COHORT', 'MHI_COHORT',
#        'MTR_COHORT', 'MWH_COHORT', 'PPCSTOT', 'MATH_NUM', 'MATH_PCT',
#        'READ_NUM', 'READ_PCT'],
#       dtype='object')

# %% [markdown]
# **NY Regression**

# %% [markdown]
# **Gradient Boosting Regressor**

# %%
#use y and x from the regression variables
y = y_reg
X = X_reg

# %%
#split the data and assign parameters
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=42)

params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,}

# %%
#initialize, fit and predict 
reg = ensemble.GradientBoostingRegressor(**params)
reg.fit(X_train, y_train)

pred = reg.predict(X_test)

# %%
#get score for training data
print(reg.score(X_train, y_train))
# Out:
# 0.9189765164625932

# %%
#get score for testing data
print(reg.score(X_test, y_test))
# Out:
# 0.45575582965074923

# %% [markdown]
# Since the score is better for training than testing, the model is overfitting. It can be improved with cross validation or regularization.

# %% [markdown]
# **NY Classification**

# %% [markdown]
# **LinearSVC**

# %%
#set x and y as classification variables
y = y_clf
X = X_clf

# %%
#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=42)

# %%
#initialize, fit and predict
clf = make_pipeline(StandardScaler(), LinearSVC(random_state=0, tol=1e-5))
clf.fit(X_train, y_train)

pred = clf.predict(X_test)

#generate classification report
print("Classification Report:\n", classification_report(y_test, pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        12
#            1       0.98      0.98      0.98       177
#
#     accuracy                           0.97       189
#    macro avg       0.87      0.87      0.87       189
# weighted avg       0.97      0.97      0.97       189

# %%
#generate ROC curve
metrics.plot_roc_curve(clf, X_test, y_test)

# %%
#plot comfusion matrix
plot_confusion_matrix(clf, X_test, y_test)  
plt.show()

# %% [markdown]
# **Random Forest**

# %%
#initialize, fit and train
clf = RandomForestClassifier(n_estimators=500, n_jobs=4)
clf.fit(X_train, y_train)
pred = clf.predict(X_test)

# %%
#generate classification report
print("Classification Report:\n", classification_report(y_test, pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82        12
#            1       0.98      0.99      0.99       177
#
#     accuracy                           0.98       189
#    macro avg       0.94      0.87      0.90       189
# weighted avg       0.98      0.98      0.98       189

# %%
#plot feature importances
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)

plt.figure(figsize =(8,6))
plt.title("Feature importances")
plt.barh(range(X.shape[1]), importances[indices],
       color="r", xerr=std[indices], align="center")

plt.yticks(range(X.shape[1]), [feature_names[i] for i in indices])
plt.ylim([-1, X.shape[1]])
plt.show()

# %% [markdown]
# **Logistic Regression**

# %%
# define models and parameters
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X_train, y_train)
pred = grid_result.predict(X_test)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.976445 using {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.969644 (0.019858) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.966579 (0.021779) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.965821 (0.023351) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.969626 (0.021629) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.967354 (0.022492) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.965839 (0.021761) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.969609 (0.021623) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.966596 (0.020944) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.966561 (0.020207) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.971124 (0.018598) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.967354 (0.023245) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.967354 (0.020905) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.976445 (0.019041) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.968851 (0.021590) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.965839 (0.024018) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
#generate classification report
print('Classification Report: \n',classification_report(y_test, pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72        12
#            1       0.98      0.98      0.98       177
#
#     accuracy                           0.96       189
#    macro avg       0.84      0.86      0.85       189
# weighted avg       0.96      0.96      0.96       189

# %%
#plot confusion matrix
plot_confusion_matrix(clf, X_test, y_test)  
plt.show()

# %% [markdown]
# **Lasso and Ridge**

# %%
#creating function for lasso, ridge, and logistic regression
def model_experiment(num_iter = 5, 
                     models = ['logistic', 'ridge', 'lasso'], alpha= 10, 
                     complexity = 'simple', degree = 3):
    
    x_axis = np.arange(num_iter)
    y_logistic_test = []
    y_lasso_test = []
    y_ridge_test = []
    sample_models = {}
    for i in range(num_iter):  
        if complexity == 'simple':
            ## split train_test 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
        elif complexity == 'polynomial':
            ## Create higher order terms
            poly = PolynomialFeatures(degree=degree)
            Xp = poly.fit_transform(X)
            ## test-train split
            X_train, X_test, y_train, y_test = train_test_split(Xp, y, test_size = 0.2)

        ## Standard scale mean = 0, variance = 1
        sd = StandardScaler()

        sd.fit(X_train)

        X_train = sd.transform(X_train)

        X_test = sd.transform(X_test)

        ## Vanilla model
        if 'logistic' in models:
            logistic = LogisticRegression()
            logistic.fit(X_train, y_train)
            sample_models['logistic'] = logistic
            test_score = logistic.score(X_test, y_test)
            train_score = logistic.score(X_train, y_train)
            y_logistic_test.append(test_score)

        if 'ridge' in models:
            ## Ridge in the simple setting
            ridge = Ridge(alpha = alpha, max_iter= 10000)
            ridge.fit(X_train, y_train)
            sample_models['ridge'] = ridge
            y_ridge_test.append(ridge.score(X_test, y_test))

        if 'lasso' in models:
            ## Lasso in the simple setting
            lasso = Lasso(alpha = alpha, max_iter= 10000)
            lasso.fit(X_train, y_train)           
            sample_models['lasso'] = lasso           
            y_lasso_test.append(lasso.score(X_test, y_test))

        i+=1
    if 'logistic' in models:
        plt.plot(y_logistic_test, label = 'logistic')
    if 'ridge' in models:
        plt.plot(y_ridge_test, label = 'ridge')
    if 'lasso' in models:
        plt.plot(y_lasso_test, label = 'lasso')
    plt.ylabel('R2 test score')
    plt.xlabel('number of iterations')
    all_results = y_logistic_test + y_lasso_test + y_ridge_test
    plt.ylim((np.min(all_results), np.max(all_results)))
    
    plt.legend()
    return sample_models

trained_models = model_experiment(num_iter=30, alpha = 15,
                                   models = ['logistic', 'ridge', 'lasso'], 
                                   complexity= 'polynomial', degree = 2)

# %% [markdown]
# **Neural Networks**

# %%
#scale the data
sc = StandardScaler() 
X_train = sc.fit_transform(X_train) 
X_test = sc.transform(X_test)

# %%
# Create the Neural Network
def create_model(learning_rate, dropout_rate): 
  model = Sequential() 
  model.add(Dense(12, input_dim=X_train.shape[1], activation='relu')) 
  model.add(Dropout(dropout_rate)) 
  model.add(Dense(6, activation='relu')) 
  model.add(Dropout(dropout_rate)) 
  model.add(Dense(1, activation='sigmoid')) 
  adam = Adam(lr=learning_rate) 
  model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
  return model

# %%
#set values for dropout_rate, epochs, batch_size, and learn_rate
dropout_rate = 0.1 
epochs = 50 
batch_size = 1 
learn_rate = 0.001

# %%
#call the neural network function
model = create_model(learn_rate, dropout_rate)

# %%
#visualize the model history of the neural network
model_history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# 351/351 [==============================] - 1s 3ms/step - loss: 0.4388 - accuracy: 0.9231 - val_loss: 0.2171 - val_accuracy: 0.9432
# Epoch 2/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.1784 - accuracy: 0.9516 - val_loss: 0.1031 - val_accuracy: 0.9545
# Epoch 3/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.1011 - accuracy: 0.9573 - val_loss: 0.0747 - val_accuracy: 0.9545
# Epoch 4/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0845 - accuracy: 0.9630 - val_loss: 0.0672 - val_accuracy: 0.9545
# Epoch 5/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0726 - accuracy: 0.9687 - val_loss: 0.0603 - val_accuracy: 0.9886
# Epoch 6/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0767 - accuracy: 0.9658 - val_loss: 0.0570 - val_accuracy: 0.9886
# Epoch 7/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0520 - accuracy: 0.9715 - val_loss: 0.0506 - val_accuracy: 0.9886
# Epoch 8/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0450 - accuracy: 0.9858 - val_loss: 0.0486 - val_accuracy: 0.9886
# Epoch 9/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0458 - accuracy: 0.9829 - val_loss: 0.0484 - val_accuracy: 0.9886
# Epoch 10/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0401 - accuracy: 0.9829 - val_loss: 0.0461 - val_accuracy: 0.9886
# Epoch 11/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0404 - accuracy: 0.9829 - val_loss: 0.0476 - val_accuracy: 0.9886
# Epoch 12/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0385 - accuracy: 0.9772 - val_loss: 0.0474 - val_accuracy: 0.9886
# Epoch 13/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0348 - accuracy: 0.9829 - val_loss: 0.0493 - val_accuracy: 0.9886
# Epoch 14/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0427 - accuracy: 0.9744 - val_loss: 0.0494 - val_accuracy: 0.9886
# Epoch 15/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0260 - accuracy: 0.9858 - val_loss: 0.0539 - val_accuracy: 0.9886
# Epoch 16/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0397 - accuracy: 0.9858 - val_loss: 0.0541 - val_accuracy: 0.9886
# Epoch 17/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0347 - accuracy: 0.9801 - val_loss: 0.0600 - val_accuracy: 0.9886
# Epoch 18/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0493 - accuracy: 0.9744 - val_loss: 0.0609 - val_accuracy: 0.9886
# Epoch 19/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0271 - accuracy: 0.9858 - val_loss: 0.0628 - val_accuracy: 0.9886
# Epoch 20/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0279 - accuracy: 0.9858 - val_loss: 0.0668 - val_accuracy: 0.9886
# Epoch 21/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0326 - accuracy: 0.9829 - val_loss: 0.0637 - val_accuracy: 0.9886
# Epoch 22/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0324 - accuracy: 0.9772 - val_loss: 0.0587 - val_accuracy: 0.9886
# Epoch 23/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0306 - accuracy: 0.9801 - val_loss: 0.0622 - val_accuracy: 0.9886
# Epoch 24/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0224 - accuracy: 0.9915 - val_loss: 0.0683 - val_accuracy: 0.9886
# Epoch 25/50
# 351/351 [==============================] - 1s 3ms/step - loss: 0.0299 - accuracy: 0.9858 - val_loss: 0.0678 - val_accuracy: 0.9886
# Epoch 26/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0308 - accuracy: 0.9829 - val_loss: 0.0709 - val_accuracy: 0.9886
# Epoch 27/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0277 - accuracy: 0.9829 - val_loss: 0.0759 - val_accuracy: 0.9886
# Epoch 28/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0196 - accuracy: 0.9886 - val_loss: 0.0765 - val_accuracy: 0.9886
# Epoch 29/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0166 - accuracy: 0.9943 - val_loss: 0.0778 - val_accuracy: 0.9886
# Epoch 30/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0192 - accuracy: 0.9915 - val_loss: 0.0791 - val_accuracy: 0.9886
# Epoch 31/50
# 351/351 [==============================] - 1s 3ms/step - loss: 0.0209 - accuracy: 0.9915 - val_loss: 0.0809 - val_accuracy: 0.9886
# Epoch 32/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0208 - accuracy: 0.9886 - val_loss: 0.0840 - val_accuracy: 0.9886
# Epoch 33/50
# 351/351 [==============================] - 1s 3ms/step - loss: 0.0200 - accuracy: 0.9886 - val_loss: 0.0919 - val_accuracy: 0.9886
# Epoch 34/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0113 - accuracy: 0.9943 - val_loss: 0.0926 - val_accuracy: 0.9886
# Epoch 35/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0241 - accuracy: 0.9858 - val_loss: 0.0821 - val_accuracy: 0.9886
# Epoch 36/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0153 - accuracy: 0.9915 - val_loss: 0.0840 - val_accuracy: 0.9886
# Epoch 37/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0139 - accuracy: 0.9943 - val_loss: 0.0853 - val_accuracy: 0.9886
# Epoch 38/50
# 351/351 [==============================] - 1s 3ms/step - loss: 0.0185 - accuracy: 0.9943 - val_loss: 0.0913 - val_accuracy: 0.9886
# Epoch 39/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0221 - accuracy: 0.9858 - val_loss: 0.0850 - val_accuracy: 0.9886
# Epoch 40/50
# 351/351 [==============================] - 1s 3ms/step - loss: 0.0176 - accuracy: 0.9915 - val_loss: 0.0982 - val_accuracy: 0.9886
# Epoch 41/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0202 - accuracy: 0.9886 - val_loss: 0.1029 - val_accuracy: 0.9886
# Epoch 42/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0117 - accuracy: 0.9943 - val_loss: 0.1070 - val_accuracy: 0.9886
# Epoch 43/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0203 - accuracy: 0.9858 - val_loss: 0.1012 - val_accuracy: 0.9886
# Epoch 44/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0125 - accuracy: 0.9943 - val_loss: 0.1140 - val_accuracy: 0.9886
# Epoch 45/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0130 - accuracy: 0.9886 - val_loss: 0.1132 - val_accuracy: 0.9886
# Epoch 46/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0145 - accuracy: 0.9915 - val_loss: 0.0976 - val_accuracy: 0.9886
# Epoch 47/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0110 - accuracy: 0.9943 - val_loss: 0.1057 - val_accuracy: 0.9886
# Epoch 48/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0119 - accuracy: 0.9915 - val_loss: 0.1172 - val_accuracy: 0.9886
# Epoch 49/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0100 - accuracy: 0.9943 - val_loss: 0.1041 - val_accuracy: 0.9886
# Epoch 50/50
# 351/351 [==============================] - 1s 2ms/step - loss: 0.0130 - accuracy: 0.9915 - val_loss: 0.1065 - val_accuracy: 0.9886

# %%
#get the loss and accuracies
accuracies = model.evaluate(X_test, y_test, verbose=1) 
print('Test Score:', accuracies[0]) 
print('Test Accuracy:', accuracies[1])
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5215 - accuracy: 0.9577
# Test Score: 0.5215118527412415
# Test Accuracy: 0.9576719403266907

# %%
#plot accuracy for test and train data from the model history
plt.plot(model_history.history['accuracy'], label = 'accuracy') 
plt.plot(model_history.history['val_accuracy'], label = 'val_accuracy') 
plt.legend(['train', 'test'])

# %%
#plot loss for test and train data from the model history
plt.plot(model_history.history['loss'], label = 'loss') 
plt.plot(model_history.history['val_loss'], label = 'val_loss') 
plt.legend(['train','test'])

# %% [markdown]
# **Unsupervised Learning** Clustering for NY

# %%
# Scaling the data so that all the features become comparable 
scaler = StandardScaler() 
X_scaled = scaler.fit_transform(X) 
  
# Normalizing the data so that the data approximately  
# follows a Gaussian distribution 
X_normalized = normalize(X_scaled) 
  
# Converting the numpy array into a pandas DataFrame 
X_normalized = pd.DataFrame(X_normalized)

# %%
pca = PCA(n_components = 2) 
X_principal = pca.fit_transform(X_normalized) 
X_principal = pd.DataFrame(X_principal) 
X_principal.columns = ['P1', 'P2']

# %%
ac2 = AgglomerativeClustering(n_clusters = 2) 
  
# Visualizing the clustering 
plt.figure(figsize =(6, 6)) 
plt.scatter(X_principal['P1'], X_principal['P2'],  
           c = ac2.fit_predict(X_principal), cmap ='rainbow') 
plt.show()

# %%
ac3 = AgglomerativeClustering(n_clusters = 3) 
  
plt.figure(figsize =(6, 6)) 
plt.scatter(X_principal['P1'], X_principal['P2'], 
           c = ac3.fit_predict(X_principal), cmap ='rainbow') 
plt.show()

# %%
ac4 = AgglomerativeClustering(n_clusters = 4) 
  
plt.figure(figsize =(6, 6)) 
plt.scatter(X_principal['P1'], X_principal['P2'], 
           c = ac4.fit_predict(X_principal), cmap ='rainbow') 
plt.show()

# %%
k = [2, 3, 4] 
  
# Appending the silhouette scores of the different models to the list 
silhouette_scores = [] 
silhouette_scores.append( 
        silhouette_score(X_principal, ac2.fit_predict(X_principal))) 
silhouette_scores.append( 
        silhouette_score(X_principal, ac3.fit_predict(X_principal))) 
silhouette_scores.append( 
        silhouette_score(X_principal, ac4.fit_predict(X_principal)))

# %%
# Plotting a bar graph to compare the results 
plt.bar(k, silhouette_scores) 
plt.title('Silhouette Scores')
plt.xlabel('Number of clusters', fontsize = 20) 
plt.ylabel('S(i)', fontsize = 20) 
plt.show()

# %%
#NY FINANCE - STUFF

# %% [markdown]
# **Using Lazy Predict on DMV Data to find the best Models**

# %% [markdown]
# **Lazy Regressor**

# %%
#setting y variable for regression
y_reg= dmv_regression.pop('ALL_RATE')
y_reg=y_reg.astype('int')

# %%
#setting x variable for regression
X_reg = dmv_regression.values
X_reg.shape
# Out:
# (560, 18)

# %%
#split the data
X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(X_reg, y_reg, test_size= 0.3, random_state=42)

# %%
#initialize the lazyregressor
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)

# %%
#fit the data
models, predictions = reg.fit(X_reg_train, X_reg_test, y_reg_train, y_reg_test)
# Out:
# 100%|██████████| 42/42 [00:03<00:00, 11.48it/s]

# %%
#visualize the results
data=pd.DataFrame(models)
data
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.70       0.74  7.82        0.21
# ExtraTreesRegressor                          0.70       0.73  7.84        0.24
# BaggingRegressor                             0.68       0.71  8.17        0.06
# RandomForestRegressor                        0.66       0.69  8.43        0.44
# KNeighborsRegressor                          0.60       0.64  9.13        0.02
# AdaBoostRegressor                            0.59       0.63  9.21        0.14
# XGBRegressor                                 0.59       0.63  9.25        0.11
# TransformedTargetRegressor                   0.57       0.62  9.43        0.01
# LinearRegression                             0.57       0.62  9.43        0.01
# Ridge                                        0.57       0.61  9.45        0.01
# LassoLarsIC                                  0.56       0.61  9.55        0.02
# BayesianRidge                                0.55       0.60  9.61        0.01
# RidgeCV                                      0.55       0.60  9.64        0.01
# LGBMRegressor                                0.54       0.59  9.73        0.09
# PoissonRegressor                             0.54       0.59  9.77        0.02
# SGDRegressor                                 0.53       0.58  9.84        0.01
# HistGradientBoostingRegressor                0.53       0.58  9.86        0.33
# ElasticNetCV                                 0.51       0.56 10.06        0.08
# HuberRegressor                               0.51       0.56 10.09        0.04
# LinearSVR                                    0.50       0.55 10.20        0.02
# LassoCV                                      0.49       0.55 10.25        0.09
# LassoLarsCV                                  0.49       0.54 10.29        0.04
# LarsCV                                       0.48       0.54 10.33        0.09
# Lasso                                        0.44       0.50 10.72        0.02
# OrthogonalMatchingPursuitCV                  0.44       0.50 10.77        0.02
# ElasticNet                                   0.42       0.48 10.95        0.01
# GammaRegressor                               0.40       0.46 11.14        0.01
# GeneralizedLinearRegressor                   0.40       0.46 11.14        0.04
# TweedieRegressor                             0.40       0.46 11.14        0.01
# ExtraTreeRegressor                           0.35       0.42 11.61        0.02
# DecisionTreeRegressor                        0.34       0.41 11.64        0.02
# OrthogonalMatchingPursuit                    0.28       0.36 12.18        0.04
# PassiveAggressiveRegressor                   0.22       0.31 12.67        0.01
# NuSVR                                        0.19       0.28 12.91        0.06
# SVR                                          0.18       0.26 13.04        0.03
# DummyRegressor                              -0.12      -0.00 15.22        0.01
# LassoLars                                   -0.12      -0.00 15.22        0.02
# RANSACRegressor                             -4.23      -3.66 32.84        0.11
# MLPRegressor                                -5.06      -4.40 35.36        0.95
# GaussianProcessRegressor                    -7.28      -6.38 41.32        0.04
# Lars                                       -11.57     -10.22 50.93        0.03
# KernelRidge                                -34.39     -30.57 85.46        0.03

# %% [markdown]
# **Lazy Classifier**

# %%
#set y variable for classification
y_clf = dmv_classification.pop('Success_Rate')
y_clf=y_clf.astype('int')

# %%
#set x variable for classification
X_clf = dmv_classification.values

# %%
#split the data
X_clf_train, X_clf_test, y_clf_train, y_clf_test = train_test_split(X_clf, y_clf, test_size= 0.3, random_state=42)

# %%
#initialize the lazyclassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric = None)

# %%
#fit the data
models, predictions = clf.fit(X_clf_train, X_clf_test, y_clf_train, y_clf_test)
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 24.75it/s]

# %%
#visualize the results
data=pd.DataFrame(models)
data
# Out:
#                                Accuracy  ...  Time Taken
# Model                                    ...
# LinearSVC                          0.97  ...        0.03
# BaggingClassifier                  0.96  ...        0.05
# ExtraTreesClassifier               0.96  ...        0.15
# GaussianNB                         0.89  ...        0.02
# LogisticRegression                 0.96  ...        0.04
# RandomForestClassifier             0.95  ...        0.20
# LinearDiscriminantAnalysis         0.95  ...        0.03
# NearestCentroid                    0.88  ...        0.02
# AdaBoostClassifier                 0.96  ...        0.14
# KNeighborsClassifier               0.94  ...        0.02
# LabelSpreading                     0.93  ...        0.04
# LabelPropagation                   0.93  ...        0.03
# QuadraticDiscriminantAnalysis      0.93  ...        0.02
# BernoulliNB                        0.83  ...        0.02
# DecisionTreeClassifier             0.95  ...        0.02
# ExtraTreeClassifier                0.94  ...        0.01
# SVC                                0.93  ...        0.02
# XGBClassifier                      0.93  ...        0.05
# RidgeClassifier                    0.95  ...        0.02
# SGDClassifier                      0.95  ...        0.02
# LGBMClassifier                     0.94  ...        0.08
# RidgeClassifierCV                  0.95  ...        0.03
# PassiveAggressiveClassifier        0.92  ...        0.02
# Perceptron                         0.92  ...        0.02
# CalibratedClassifierCV             0.90  ...        0.06
# DummyClassifier                    0.83  ...        0.01
#
# [26 rows x 5 columns]

# %%
#get feature names for future use
feature_names = dmv_classification.columns
print(feature_names)
# Out:
# Index(['TOTFRL', 'FTE', 'STUTERATIO', 'TOTMENROL', 'TOTFENROL', 'SCHOOL_TYPE',
#        'ALL_COHORT', 'MAM_COHORT', 'MAS_COHORT', 'MBL_COHORT', 'MHI_COHORT',
#        'MTR_COHORT', 'MWH_COHORT', 'PPCSTOT', 'MATH_NUM', 'MATH_PCT',
#        'READ_NUM', 'READ_PCT'],
#       dtype='object')

# %% [markdown]
# **DMV Regression**

# %% [markdown]
# **GradientBoosting Regressor**

# %%
#set a and y to regressor variables
y = y_reg
X = X_reg

# %%
#split the data and assign parameters
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=42)

params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,}

# %%
#initialize, fit and predict 
reg = ensemble.GradientBoostingRegressor(**params)
reg.fit(X_train, y_train)

pred = reg.predict(X_test)

# %%
#get score for train data
reg.score(X_train, y_train)
# Out:
# 0.9633464966618498

# %%
#get score for test data
reg.score(X_test, y_test)
# Out:
# 0.6959032719654595

# %% [markdown]
# Since the score is better for training than testing, the model is overfitting. It can be improved with cross validation or regularization.

# %% [markdown]
# **DMV Classification**

# %% [markdown]
# **LinearSVC**

# %%
#set x and y to classification variables
y = y_clf
X = X_clf

# %%
#split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state=42)

# %%
#initialize, fit and predict
clf = make_pipeline(StandardScaler(), LinearSVC(random_state=0, tol=1e-5))
clf.fit(X_train, y_train)

pred = clf.predict(X_test)

#generate classification report
print("Classification Report:\n", classification_report(y_test, pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.94      0.87        18
#            1       0.99      0.97      0.98       150
#
#     accuracy                           0.97       168
#    macro avg       0.90      0.96      0.93       168
# weighted avg       0.97      0.97      0.97       168

# %%
#generate ROC curve
metrics.plot_roc_curve(clf, X_test, y_test)

# %%
#plot confusion matrix
plot_confusion_matrix(clf, X_test, y_test)  
plt.show()

# %% [markdown]
# **Random Forest**

# %%
#initialize, fit and predict
clf = RandomForestClassifier(n_estimators=500, n_jobs=4)
clf.fit(X_train, y_train)
pred = clf.predict(X_test)

# %%
print("Classification Report:\n", classification_report(y_test, pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.83      0.75        18
#            1       0.98      0.95      0.97       150
#
#     accuracy                           0.94       168
#    macro avg       0.83      0.89      0.86       168
# weighted avg       0.95      0.94      0.94       168

# %%
print(accuracy_score(y_test, pred))
# Out:
# 0.9404761904761905

# %% [markdown]
# Random forest accuracy score is better for NY compared to DMV

# %%
#get feature importances
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)

plt.figure(figsize =(8,6))
plt.title("Feature importances")
plt.barh(range(X.shape[1]), importances[indices],
       color="r", xerr=std[indices], align="center")

plt.yticks(range(X.shape[1]), [feature_names[i] for i in indices])
plt.ylim([-1, X.shape[1]])
plt.show()

# %% [markdown]
# **Logistic Regression**

# %%
# define models and parameters
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X_train, y_train)
pred = grid_result.predict(X_test)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.971111 using {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.955791 (0.024630) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.969402 (0.022249) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.959167 (0.024405) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.954936 (0.026149) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.963440 (0.026922) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.958333 (0.023310) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.959188 (0.026897) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.966004 (0.023090) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.961752 (0.024442) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.965150 (0.025097) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.962585 (0.026143) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.966859 (0.025660) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.969423 (0.021195) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.971111 (0.021569) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.967714 (0.021755) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
print('Classification Report: \n',classification_report(y_test, pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70        18
#            1       0.97      0.96      0.96       150
#
#     accuracy                           0.93       168
#    macro avg       0.83      0.84      0.83       168
# weighted avg       0.94      0.93      0.94       168

# %%
plot_confusion_matrix(clf, X_test, y_test)  
plt.show()

# %% [markdown]
# **Lasso and Ridge**

# %%
#create function for lasso, ridge and logistic regression
def model_experiment(num_iter = 5, 
                     models = ['logistic', 'ridge', 'lasso'], alpha= 10, 
                     complexity = 'simple', degree = 3):
    
    x_axis = np.arange(num_iter)
    y_logistic_test = []
    y_lasso_test = []
    y_ridge_test = []
    sample_models = {}
    for i in range(num_iter):        
        if complexity == 'simple':
            ## split train_test 
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
        elif complexity == 'polynomial':
            ## Create higher order terms
            poly = PolynomialFeatures(degree=degree)
            Xp = poly.fit_transform(X)
            ## test-train split
            X_train, X_test, y_train, y_test = train_test_split(Xp, y, test_size = 0.2)

        ## Standard scale mean = 0, variance = 1
        sd = StandardScaler()
        sd.fit(X_train)
        X_train = sd.transform(X_train)
        X_test = sd.transform(X_test)

        ## Vanilla model
        if 'logistic' in models:
            logistic = LogisticRegression()
            logistic.fit(X_train, y_train)    
            sample_models['logistic'] = logistic
            test_score = logistic.score(X_test, y_test)
            train_score = logistic.score(X_train, y_train)
            y_logistic_test.append(test_score)

        if 'ridge' in models:
            ## Ridge in the simple setting
            ridge = Ridge(alpha = alpha, max_iter= 10000)
            ridge.fit(X_train, y_train)
            sample_models['ridge'] = ridge
            y_ridge_test.append(ridge.score(X_test, y_test))

        if 'lasso' in models:
            ## Lasso in the simple setting
            lasso = Lasso(alpha = alpha, max_iter= 10000)
            lasso.fit(X_train, y_train)           
            sample_models['lasso'] = lasso           
            y_lasso_test.append(lasso.score(X_test, y_test))                                                       

        i+=1
    if 'logistic' in models:
        plt.plot(y_logistic_test, label = 'logistic')
    if 'ridge' in models:
        plt.plot(y_ridge_test, label = 'ridge')
    if 'lasso' in models:
        plt.plot(y_lasso_test, label = 'lasso')
    plt.ylabel('R2 test score')
    plt.xlabel('number of iterations')
    all_results = y_logistic_test + y_lasso_test + y_ridge_test
    plt.ylim((np.min(all_results), np.max(all_results)))
    
    plt.legend()
    return sample_models

trained_models = model_experiment(num_iter=30, alpha = 15,
                                   models = ['logistic', 'ridge', 'lasso'], 
                                   complexity= 'polynomial', degree = 2)

# %% [markdown]
# **Neural Networks**

# %%
#scale the data
sc = StandardScaler() 
X_train = sc.fit_transform(X_train) 
X_test = sc.transform(X_test)

# %%
# Create the Neural Network
def create_model(learning_rate, dropout_rate): 
  model = Sequential() 
  model.add(Dense(12, input_dim=X_train.shape[1], activation='relu')) 
  model.add(Dropout(dropout_rate)) 
  model.add(Dense(6, activation='relu')) 
  model.add(Dropout(dropout_rate)) 
  model.add(Dense(1, activation='sigmoid')) 
  adam = Adam(lr=learning_rate) 
  model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
  return model

# %%
dropout_rate = 0.1 
epochs = 50 
batch_size = 1 
learn_rate = 0.001

# %%
model = create_model(learn_rate, dropout_rate)

# %%
model_history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4208 - accuracy: 0.9073 - val_loss: 0.2147 - val_accuracy: 0.9620
# Epoch 2/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2517 - accuracy: 0.9105 - val_loss: 0.1324 - val_accuracy: 0.9620
# Epoch 3/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2195 - accuracy: 0.9105 - val_loss: 0.1234 - val_accuracy: 0.9620
# Epoch 4/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2049 - accuracy: 0.9042 - val_loss: 0.1168 - val_accuracy: 0.9620
# Epoch 5/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1797 - accuracy: 0.9137 - val_loss: 0.1189 - val_accuracy: 0.9494
# Epoch 6/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1745 - accuracy: 0.9265 - val_loss: 0.1089 - val_accuracy: 0.9494
# Epoch 7/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1557 - accuracy: 0.9329 - val_loss: 0.0964 - val_accuracy: 0.9494
# Epoch 8/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1492 - accuracy: 0.9393 - val_loss: 0.0916 - val_accuracy: 0.9620
# Epoch 9/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1207 - accuracy: 0.9457 - val_loss: 0.0778 - val_accuracy: 0.9747
# Epoch 10/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1349 - accuracy: 0.9457 - val_loss: 0.0740 - val_accuracy: 0.9747
# Epoch 11/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1276 - accuracy: 0.9521 - val_loss: 0.0842 - val_accuracy: 0.9747
# Epoch 12/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1097 - accuracy: 0.9489 - val_loss: 0.0793 - val_accuracy: 0.9747
# Epoch 13/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1216 - accuracy: 0.9457 - val_loss: 0.0736 - val_accuracy: 0.9747
# Epoch 14/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1104 - accuracy: 0.9553 - val_loss: 0.0839 - val_accuracy: 0.9747
# Epoch 15/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1102 - accuracy: 0.9393 - val_loss: 0.0692 - val_accuracy: 0.9747
# Epoch 16/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1054 - accuracy: 0.9425 - val_loss: 0.0729 - val_accuracy: 0.9747
# Epoch 17/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1052 - accuracy: 0.9649 - val_loss: 0.0689 - val_accuracy: 0.9747
# Epoch 18/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1019 - accuracy: 0.9521 - val_loss: 0.0664 - val_accuracy: 0.9747
# Epoch 19/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1081 - accuracy: 0.9425 - val_loss: 0.0665 - val_accuracy: 0.9747
# Epoch 20/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0707 - accuracy: 0.9649 - val_loss: 0.0675 - val_accuracy: 0.9747
# Epoch 21/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0690 - accuracy: 0.9681 - val_loss: 0.0607 - val_accuracy: 0.9747
# Epoch 22/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0805 - accuracy: 0.9617 - val_loss: 0.0667 - val_accuracy: 0.9747
# Epoch 23/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0986 - accuracy: 0.9585 - val_loss: 0.0670 - val_accuracy: 0.9747
# Epoch 24/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0697 - accuracy: 0.9776 - val_loss: 0.0705 - val_accuracy: 0.9747
# Epoch 25/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0773 - accuracy: 0.9776 - val_loss: 0.0573 - val_accuracy: 0.9747
# Epoch 26/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0807 - accuracy: 0.9681 - val_loss: 0.0631 - val_accuracy: 0.9747
# Epoch 27/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0981 - accuracy: 0.9712 - val_loss: 0.0702 - val_accuracy: 0.9747
# Epoch 28/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0749 - accuracy: 0.9712 - val_loss: 0.0682 - val_accuracy: 0.9747
# Epoch 29/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0714 - accuracy: 0.9744 - val_loss: 0.0544 - val_accuracy: 0.9747
# Epoch 30/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0595 - accuracy: 0.9840 - val_loss: 0.0581 - val_accuracy: 0.9747
# Epoch 31/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0691 - accuracy: 0.9681 - val_loss: 0.0540 - val_accuracy: 0.9747
# Epoch 32/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0870 - accuracy: 0.9712 - val_loss: 0.0536 - val_accuracy: 0.9747
# Epoch 33/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0533 - accuracy: 0.9808 - val_loss: 0.0544 - val_accuracy: 0.9747
# Epoch 34/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0570 - accuracy: 0.9840 - val_loss: 0.0662 - val_accuracy: 0.9747
# Epoch 35/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0673 - accuracy: 0.9744 - val_loss: 0.0535 - val_accuracy: 0.9747
# Epoch 36/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0428 - accuracy: 0.9872 - val_loss: 0.0751 - val_accuracy: 0.9747
# Epoch 37/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0432 - accuracy: 0.9840 - val_loss: 0.0662 - val_accuracy: 0.9747
# Epoch 38/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0437 - accuracy: 0.9840 - val_loss: 0.0334 - val_accuracy: 0.9747
# Epoch 39/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0439 - accuracy: 0.9872 - val_loss: 0.0699 - val_accuracy: 0.9747
# Epoch 40/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0536 - accuracy: 0.9872 - val_loss: 0.0375 - val_accuracy: 0.9747
# Epoch 41/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0435 - accuracy: 0.9840 - val_loss: 0.0763 - val_accuracy: 0.9747
# Epoch 42/50
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0436 - accuracy: 0.9872 - val_loss: 0.0268 - val_accuracy: 0.9873
# Epoch 43/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0519 - accuracy: 0.9808 - val_loss: 0.0462 - val_accuracy: 0.9747
# Epoch 44/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0300 - accuracy: 0.9936 - val_loss: 0.0575 - val_accuracy: 0.9747
# Epoch 45/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0371 - accuracy: 0.9808 - val_loss: 0.0173 - val_accuracy: 1.0000
# Epoch 46/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0535 - accuracy: 0.9776 - val_loss: 0.0342 - val_accuracy: 0.9747
# Epoch 47/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0538 - accuracy: 0.9808 - val_loss: 0.0586 - val_accuracy: 0.9747
# Epoch 48/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0261 - accuracy: 0.9968 - val_loss: 0.0696 - val_accuracy: 0.9747
# Epoch 49/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0406 - accuracy: 0.9808 - val_loss: 0.0716 - val_accuracy: 0.9747
# Epoch 50/50
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0560 - accuracy: 0.9840 - val_loss: 0.0695 - val_accuracy: 0.9747

# %%
accuracies = model.evaluate(X_test, y_test, verbose=1) 
print('Test Score:', accuracies[0]) 
print('Test Accuracy:', accuracies[1])
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1505 - accuracy: 0.9524
# Test Score: 0.15051953494548798
# Test Accuracy: 0.9523809552192688

# %%
plt.plot(model_history.history['accuracy'], label = 'accuracy') 
plt.plot(model_history.history['val_accuracy'], label = 'val_accuracy') 
plt.legend(['train', 'test'])

# %%
plt.plot(model_history.history['loss'], label = 'loss') 
plt.plot(model_history.history['val_loss'], label = 'val_loss') 
plt.legend(['train','test'])

# %% [markdown]
# **Unsupervised Learning** Clustering for DMV

# %%
# Scaling the data so that all the features become comparable 
scaler = StandardScaler() 
X_scaled = scaler.fit_transform(X) 
  
# Normalizing the data so that the data approximately  
# follows a Gaussian distribution 
X_normalized = normalize(X_scaled) 
  
# Converting the numpy array into a pandas DataFrame 
X_normalized = pd.DataFrame(X_normalized)

# %%
pca = PCA(n_components = 2) 
X_principal = pca.fit_transform(X_normalized) 
X_principal = pd.DataFrame(X_principal) 
X_principal.columns = ['P1', 'P2']

# %%
ac2 = AgglomerativeClustering(n_clusters = 2) 
  
# Visualizing the clustering 
plt.figure(figsize =(6, 6)) 
plt.scatter(X_principal['P1'], X_principal['P2'],  
           c = ac2.fit_predict(X_principal), cmap ='rainbow') 
plt.show()

# %%
ac3 = AgglomerativeClustering(n_clusters = 3) 
  
plt.figure(figsize =(6, 6)) 
plt.scatter(X_principal['P1'], X_principal['P2'], 
           c = ac3.fit_predict(X_principal), cmap ='rainbow') 
plt.show()

# %%
ac4 = AgglomerativeClustering(n_clusters = 4) 
  
plt.figure(figsize =(6, 6)) 
plt.scatter(X_principal['P1'], X_principal['P2'], 
           c = ac4.fit_predict(X_principal), cmap ='rainbow') 
plt.show()

# %%
k = [2, 3, 4] 
  
# Appending the silhouette scores of the different models to the list 
silhouette_scores = [] 
silhouette_scores.append( 
        silhouette_score(X_principal, ac2.fit_predict(X_principal))) 
silhouette_scores.append( 
        silhouette_score(X_principal, ac3.fit_predict(X_principal))) 
silhouette_scores.append( 
        silhouette_score(X_principal, ac4.fit_predict(X_principal)))

# %%
# Plotting a bar graph to compare the results 
plt.bar(k, silhouette_scores) 
plt.title('Silhouette Scores')
plt.xlabel('Number of clusters', fontsize = 20) 
plt.ylabel('S(i)', fontsize = 20) 
plt.show()
